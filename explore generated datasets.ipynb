# %%
import pandas as pd

# %%
currensy = ('EUR_USD', 'EUR_JPY', 'EUR_CAD', 'EUR_AUD', 'AUD_USD', 'USD_CAD', 'USD_JPY')
timePeriods = ('M', 'D', 'H4')

# %%
i = 0
j = 0

# %%
df = pd.read_csv(r'Datasets/{} {}.csv'.format(currensy[i], timePeriods[j]))
j = j+1 if j<2 else 0
i = i+1 if j==0 else i
print(currensy[i], timePeriods[j])
print(df.Rejection.unique())
df.tail(125)
# Out:
# USD_CAD D
# [nan]
#                     time     Open     High      Low    Close  Rejection
# 71   2008-05-01 00:00:00  1.00759  1.02436  0.98215  0.99340        NaN
# 72   2008-06-01 00:00:00  0.99422  1.03238  0.99288  1.02037        NaN
# 73   2008-07-01 00:00:00  1.02037  1.02736  0.99746  1.02365        NaN
# 74   2008-08-01 00:00:00  1.02365  1.07286  1.02315  1.06227        NaN
# 75   2008-09-01 00:00:00  1.06227  1.08206  1.02984  1.06205        NaN
# 76   2008-10-01 00:00:00  1.06203  1.30165  1.05475  1.21200        NaN
# 77   2008-11-01 00:00:00  1.21030  1.29850  1.14625  1.24250        NaN
# 78   2008-12-01 01:00:00  1.24250  1.30076  1.18180  1.22145        NaN
# 79   2009-01-01 01:00:00  1.22165  1.27680  1.17613  1.22965        NaN
# 80   2009-02-01 01:00:00  1.22870  1.27657  1.21313  1.27657        NaN
# 81   2009-03-01 01:00:00  1.27532  1.30650  1.21908  1.26105        NaN
# 82   2009-04-01 00:00:00  1.26103  1.27175  1.18620  1.19337        NaN
# ...
